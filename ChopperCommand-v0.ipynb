# %%
import gym 
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
import os

# %%
# !python -m atari_py.import_roms .\ROMS
# Out:
# copying adventure.bin from .\ROMS\Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to C:\Users\Rajadurai\anaconda3\lib\site-packages\atari_py\atari_roms\adventure.bin
# copying air_raid.bin from .\ROMS\Air Raid (Men-A-Vision) (PAL) ~.bin to C:\Users\Rajadurai\anaconda3\lib\site-packages\atari_py\atari_roms\air_raid.bin
# copying alien.bin from .\ROMS\Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin to C:\Users\Rajadurai\anaconda3\lib\site-packages\atari_py\atari_roms\alien.bin
# copying amidar.bin from .\ROMS\Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin to C:\Users\Rajadurai\anaconda3\lib\site-packages\atari_py\atari_roms\amidar.bin
# copying assault.bin from .\ROMS\Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to C:\Users\Rajadurai\anaconda3\lib\site-packages\atari_py\atari_roms\assault.bin
# ...

# %%
environment_name = "ChopperCommand-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 3
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# C:\Users\Rajadurai\anaconda3\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# Episode:1 Score:800.0
# Episode:2 Score:600.0
# Episode:3 Score:400.0

# %%
env.close()

# %%
env.action_space.sample()
# Out:
# 13

# %%
env.action_space
# Out:
# Discrete(18)

# %%
env.observation_space.sample()
# Out:
# array([[[ 15, 221, 178],
#         [178,  72, 148],
#         [210, 200,  33],
#         ...,
#         [ 69, 126,  77],
#         [ 50, 102,   3],
#         [252,  18, 103]],
#
#        [[ 65,  15, 255],
#         [172,  51, 114],
#         [184,   9, 162],
#         ...,
#         [105, 187, 141],
#         [121, 109, 151],
#         [138, 168, 244]],
#
#        [[115, 179,   4],
#         [ 10, 125,  93],
#         [223,  80, 122],
#         ...,
#         [147,  31, 108],
#         [ 89, 152,   2],
#         [107, 221, 244]],
#
#        ...,
#
#        [[  2, 247, 132],
#         [215,  95,  53],
#         [231, 161,  72],
#         ...,
#         [186, 226, 112],
#         [191,  19,  55],
#         [109, 103, 139]],
#
#        [[  3,  30,  59],
#         [125,  32, 235],
#         [ 64,  48, 116],
#         ...,
#         [159,  31, 129],
#         [217,  55,  23],
#         [  2,  88, 167]],
#
#        [[ 23,  48, 218],
#         [ 35, 240,  29],
#         [ 40,  52, 177],
# ...

# %%
env = make_atari_env('ChopperCommand-v0', n_envs=4, seed=0)
env = VecFrameStack(env, n_stack=4)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = A2C("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=200000)
# Out:
# Logging to Training\Logs\A2C_2
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 764      |
# |    ep_rew_mean        | 700      |
# | time/                 |          |
# |    fps                | 62       |
# |    iterations         | 100      |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | 0.00886  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.0938   |
# |    value_loss         | 0.0476   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 764       |
# |    ep_rew_mean        | 700       |
# | time/                 |           |
# |    fps                | 69        |
# |    iterations         | 200       |
# ...

# %%
a2c_path = os.path.join('Training', 'Saved Models', 'A2C_ChopperCommand_model')

# %%
model.save(a2c_path)

# %%
del model

# %%
model = A2C.load(a2c_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
env = make_atari_env('ChopperCommand-v0', n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)

# %%
evaluate_policy(model, env, n_eval_episodes=5, render=True)
# Out:
# (1720.0, 658.4831053261731)

# %%
env.close()

# %%
import gym 
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
import os

env = make_atari_env('ChopperCommand-v0', n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)

a2c_path = os.path.join('Training', 'Saved Models', 'A2C_ChopperCommand_model')

model = A2C.load(a2c_path, env)

evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# Wrapping the env in a VecTransposeImage.
# (1530.0, 534.8831648126533)

# %%
env.close()
